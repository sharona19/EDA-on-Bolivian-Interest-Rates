# %% [markdown]
# # EDA analysis on the Bolivian Financial System Interest Rates

# %%
# data mining and visualization libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import rcParams
import seaborn as sns 

#estilo de las visualizaciones
#plt.style.use("ggplot")
#rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ### 1. Extracting the data

# %% [markdown]
# This dataset contains the weekly summary of the interest rates both active and passive reported by the Bolivian
# financial institutions to the Bolivian Central Bank.
# Source: https://www.bcb.gob.bo/webdocs/tasas_interes

# %%
#reading the xml file provided by the Central Bank, from the 2nd week of June, 2023
df = pd.read_excel("PUBLICACION 2023 06 18 TASAS ACT Y PAS.xlsx", sheet_name="PAS", na_values=['NA', 0])

# %%
df.head()
# Out:
#    Unnamed: 0               Entidad   ahorroB       30b      60b  90b  \
# 0         NaN                   NaN       NaN       NaN      NaN  NaN
# 1         NaN      BANCOS MÚLTIPLES       NaN       NaN      NaN  NaN
# 2         NaN                   NaN       NaN       NaN      NaN  NaN
# 3         NaN   NACIONAL DE BOLIVIA  1.929171  0.115427  0.25131  NaN
# 4         NaN  MERCANTIL SANTA CRUZ  1.549590  0.180000  0.39038  NaN
#
#        180b      360b      720b   1080b  ...  Unnamed: 26  Unnamed: 27  \
# 0       NaN       NaN       NaN     NaN  ...          NaN          NaN
# 1       NaN       NaN       NaN     NaN  ...          NaN          NaN
# 2       NaN       NaN       NaN     NaN  ...          NaN          NaN
# 3  1.507500  4.134283  2.867602  3.3694  ...          NaN          NaN
# 4  1.888729  3.190097  4.583262     NaN  ...          NaN          NaN
#
#    Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 33  Unnamed: 34  Unnamed: 35
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 2. Data Cleansing and Data Mining
# #### Removing rows and columns with NaN only

# %%
df = df.dropna(axis=0, how='all') #rows NaN
df = df.dropna(axis=1, how='all')# columns NaN

# %%
df.head()
# Out:
#                 Entidad   ahorroB       30b       60b  90b      180b  \
# 1      BANCOS MÚLTIPLES       NaN       NaN       NaN  NaN       NaN
# 3   NACIONAL DE BOLIVIA  1.929171  0.115427  0.251310  NaN  1.507500
# 4  MERCANTIL SANTA CRUZ  1.549590  0.180000  0.390380  NaN  1.888729
# 5    CRÉDITO DE BOLIVIA  0.431098  0.046430  0.117885  NaN  3.530600
# 6                  BISA  1.753244  0.032046  0.216280  NaN       NaN
#
#        360b      720b   1080b  Mayorb  ahorroUsd  30Usd  60Usd  90Usd  180Usd  \
# 1       NaN       NaN     NaN     NaN        NaN    NaN    NaN    NaN     NaN
# 3  4.134283  2.867602  3.3694     NaN     0.0100   0.01   0.01    NaN    0.07
# 4  3.190097  4.583262     NaN     NaN        NaN   0.01   0.01    NaN    0.01
# 5       NaN       NaN     NaN     NaN     0.0001   0.01   0.02    NaN     NaN
# 6  3.012100  3.950077     NaN     NaN        NaN   0.01   0.01    NaN    0.08
#
#      360Usd    720Usd  1080Usd  MayorUsd Unnamed: 35
# 1       NaN       NaN      NaN       NaN         NaN
# 3  0.133205  0.210000      NaN       NaN         NaN
# 4       NaN  0.960597      NaN       NaN         NaN
# 5       NaN       NaN      NaN       NaN         NaN
# 6       NaN       NaN      NaN       NaN         NaN

# %% [markdown]
# #### Removing rows that contain categorical values as subaggregates

# %%
#categorical_df = df[df['ahorroB'].isna()]
df = df.dropna(subset=['ahorroB'])
df.head()
# Out:
#                 Entidad   ahorroB       30b       60b  90b      180b  \
# 3   NACIONAL DE BOLIVIA  1.929171  0.115427  0.251310  NaN  1.507500
# 4  MERCANTIL SANTA CRUZ  1.549590  0.180000  0.390380  NaN  1.888729
# 5    CRÉDITO DE BOLIVIA  0.431098  0.046430  0.117885  NaN  3.530600
# 6                  BISA  1.753244  0.032046  0.216280  NaN       NaN
# 7                 UNIÓN  0.154201  0.085047  0.149656  NaN       NaN
#
#        360b      720b    1080b  Mayorb  ahorroUsd  30Usd  60Usd  90Usd  \
# 3  4.134283  2.867602  3.36940     NaN     0.0100   0.01   0.01    NaN
# 4  3.190097  4.583262      NaN     NaN        NaN   0.01   0.01    NaN
# 5       NaN       NaN      NaN     NaN     0.0001   0.01   0.02    NaN
# 6  3.012100  3.950077      NaN     NaN        NaN   0.01   0.01    NaN
# 7  4.544670  5.047221  5.04158     NaN     0.0100   0.01   0.01   0.04
#
#    180Usd    360Usd    720Usd  1080Usd  MayorUsd Unnamed: 35
# 3    0.07  0.133205  0.210000      NaN       NaN         NaN
# 4    0.01       NaN  0.960597      NaN       NaN         NaN
# 5     NaN       NaN       NaN      NaN       NaN         NaN
# 6    0.08       NaN       NaN      NaN       NaN         NaN
# 7     NaN       NaN  2.277748      NaN       NaN         NaN

# %% [markdown]
# Deleting any left useless columns or rows

# %%
df = df.drop('Unnamed: 35', axis=1)

# %% [markdown]
# #### Find duplicates

# %%
duplicates = df[df.duplicated('Entidad', keep=False)]

# Display the duplicate rows
print(duplicates)
# Out:
#      Entidad   ahorroB     30b  60b       90b    180b      360b      720b  \
# 30  PROGRESO  2.018400  0.1801  NaN  2.118602  2.1166  2.212100  4.050595
# 62  PROGRESO  1.997819  0.2503  NaN       NaN  2.0184  3.670794  5.594537
#
#      1080b  Mayorb  ahorroUsd   30Usd  60Usd  90Usd  180Usd  360Usd  720Usd  \
# 30     NaN     NaN        NaN  0.0100    NaN    NaN     NaN     NaN     NaN
# 62  6.3792  7.9777        NaN  0.0501    NaN    NaN     NaN     NaN  1.5104
#
#     1080Usd  MayorUsd
# 30      NaN       NaN
# 62      NaN       NaN

# %% [markdown]
# Data shows that there is both a Housing Financial Institution and a "Cooperativa Financial Institution" called PROGRESO.
# For that reason,the second one's name is going to be changed to diffentiate them.

# %%
#The duplicate is located in the row 62
row_index = 62
column_name = 'Entidad'
new_value = 'PROGRESO COOP' 
df.at[row_index, column_name] = new_value

# %% [markdown]
# #### Reassign available categorical variables using a dictionary

# %% [markdown]
# Dictionary

# %%
# Create a dictionary with variables as keys and their corresponding categories
# Blending 'MICROFINANZAS MULTIPLE' and 'MICROFINANZAS PYME' into a single category
category_dict = {
    'BANCOS MÚLTIPLES': ['NACIONAL DE BOLIVIA', 'MERCANTIL SANTA CRUZ','CRÉDITO DE BOLIVIA','BISA','UNIÓN','ECONÓMICO','GANADERO','NACIÓN ARGENTINA'],
    'MICROFINANZAS': ['SOLIDARIO', 'FIE','FORTALEZA','PRODEM','DE LA COMUNIDAD','ECO FUTURO'],
     'ENTIDADES FINANCIERAS DE VIVIENDA': ['LA PRIMERA','PROMOTORA','PROGRESO'],
    'COOPERATIVAS': ['JESÚS  NAZARENO','SAN MARTÍN DE PORRES','FÁTIMA','LA MERCED','SAN PEDRO','LOYOLA','CAT. TARIJA','SAN ANTONIO','PIO X','INCAHUASSI','QUILLACOLLO','S.J. PUNATA','TRINIDAD','COMARAPA','SAN ROQUE','SAN MATEO','CHOROLQUE','M. F. GAINZA','MADRE Y MAESTRA','E. G. CHACO','CAT. POTOSÍ','ASUNCIÓN','S. J. BERMEJO','MAG. RURAL',
'SAN JOAQUÍN','S.C BORROMEO','CACEF','LA SAGRADA FAMILIA','PROGRESO COOP','MAG RURAL CHUQUISACA','SAN PEDRO DE AIQUILE','SAN MARTIN','CRISTO REY CBBA','VIRGEN DE LOS REMEDIOS',
'SAN FRANCISCO SOLANO','SOLUCREDIT SAN SILVESTRE','COOPROLE','PAULO VI','HOSPICIO','CANTERA'],
    'IFDS': ['IFD CIDRE','IFD CRECER','IFD DIACONÍA','IFD FONDECO','IFD FUBODE','IFD IDEPRO','IFD IMPRO','IFD PROMUJER','IFD SARTAWI']
    
}

# %%
# Create a function to perform the reverse mapping
def get_category(row):
    for category, elements in category_dict.items():
        if row in elements:
            return category
    return None

# Step 5: Apply the function to create the new column
df['Tipo'] = df['Entidad'].apply(get_category).astype('category')

# Display the updated dataframe
df
# Out:
#                      Entidad   ahorroB       30b       60b       90b  \
# 3        NACIONAL DE BOLIVIA  1.929171  0.115427  0.251310       NaN
# 4       MERCANTIL SANTA CRUZ  1.549590  0.180000  0.390380       NaN
# 5         CRÉDITO DE BOLIVIA  0.431098  0.046430  0.117885       NaN
# 6                       BISA  1.753244  0.032046  0.216280       NaN
# 7                      UNIÓN  0.154201  0.085047  0.149656       NaN
# 8                  ECONÓMICO  1.087249  0.065127  0.201116  1.205500
# 9                   GANADERO  1.604116  0.050686  0.070014       NaN
# 16                 SOLIDARIO  2.121778  0.162463  0.397392  6.970803
# 17                       FIE  1.973674  0.129144  0.271320  1.205745
# 18                 FORTALEZA  4.072932  0.120512       NaN  1.205400
# 19                    PRODEM  1.406209  0.180000  0.500000  1.210000
# 23           DE LA COMUNIDAD  2.710278  0.101716       NaN  7.200391
# 24                ECO FUTURO  1.887255  2.688022       NaN       NaN
# 28                LA PRIMERA  2.769235  0.053945  0.186921  1.508500
# 29                 PROMOTORA  2.018400  0.200195       NaN       NaN
# 30                  PROGRESO  2.018400  0.180100       NaN  2.118602
# 34           JESÚS  NAZARENO  2.020000  0.551400  0.551400  3.546200
# 35      SAN MARTÍN DE PORRES  0.050100  0.200200       NaN  1.812200
# 36                    FÁTIMA  2.018400  0.501100       NaN  1.508500
# 37                 LA MERCED  0.100000  0.200200  0.400712  2.523500
# 38                 SAN PEDRO  2.018400  0.501100       NaN       NaN
# 39                    LOYOLA  2.018400  1.510400       NaN       NaN
# 40               CAT. TARIJA  2.018400  0.180100       NaN       NaN
# 41               SAN ANTONIO  3.452418  0.250300       NaN  3.556700
# 42                     PIO X  2.004099  0.501100       NaN  3.041700
# 43                INCAHUASSI  2.018400  0.180100       NaN  2.836200
# 44               QUILLACOLLO  2.018400  0.180100       NaN  2.528800
# 45               S.J. PUNATA  1.740693  0.586018       NaN  2.015000
# 46                  TRINIDAD  2.018400       NaN       NaN       NaN
# 47                  COMARAPA  2.003466  0.180100  0.501190       NaN
# 48                 SAN ROQUE  2.018400  0.702200  0.702238       NaN
# 49                 SAN MATEO  0.619785  0.180100       NaN  1.307800
# 50                 CHOROLQUE  1.120206  0.501100       NaN       NaN
# 51              M. F. GAINZA  2.018400  0.180100       NaN       NaN
# 52           MADRE Y MAESTRA  2.018400  0.501100       NaN  3.546200
# 53               E. G. CHACO  2.018400  0.180100       NaN       NaN
# 54               CAT. POTOSÍ  1.000000  0.200000  0.200000  2.677797
# 55                  ASUNCIÓN  2.018400  0.180100  0.501162  2.015000
# 56             S. J. BERMEJO  2.018400  0.180100  0.501103  1.205400
# 57                MAG. RURAL  2.985016  0.200200       NaN  3.556700
# 58               SAN JOAQUÍN  2.018400  0.601600       NaN  3.660000
# 59              S.C BORROMEO  2.018400  0.501100       NaN  2.523500
# 60                     CACEF  1.773433  1.407109  1.900635       NaN
# 61        LA SAGRADA FAMILIA  5.401831  0.180000       NaN       NaN
# 62             PROGRESO COOP  1.997819  0.250300       NaN       NaN
# 63      MAG RURAL CHUQUISACA  2.155440  0.180100       NaN       NaN
# 64      SAN PEDRO DE AIQUILE  2.018400  0.180100       NaN       NaN
# 65                SAN MARTIN  3.041700  3.051800       NaN       NaN
# 66           CRISTO REY CBBA  2.018400  0.300400       NaN       NaN
# 67    VIRGEN DE LOS REMEDIOS  2.018400  0.802900  1.510300       NaN
# 68      SAN FRANCISCO SOLANO  0.016977  0.180100  0.400799       NaN
# 69  SOLUCREDIT SAN SILVESTRE  2.032108  0.200200       NaN       NaN
# 71                  PAULO VI  2.018400  0.250300  2.018359  1.508500
# 72                  HOSPICIO  2.018400  0.200200  0.501200       NaN
# 73                   CANTERA  2.000000  0.180100       NaN       NaN
# 75                 IFD CIDRE  3.041700  3.556700  3.814784       NaN
# 76                IFD CRECER  2.734202  0.501100       NaN       NaN
# 77              IFD DIACONÍA  1.990461  0.180100  0.400791       NaN
# 79                IFD FUBODE  3.110509       NaN       NaN       NaN
# 82              IFD PROMUJER  2.255136       NaN       NaN       NaN
#
#         180b      360b      720b     1080b    Mayorb  ahorroUsd     30Usd  \
# 3   1.507500  4.134283  2.867602  3.369400       NaN     0.0100  0.010000
# 4   1.888729  3.190097  4.583262       NaN       NaN        NaN  0.010000
# 5   3.530600       NaN       NaN       NaN       NaN     0.0001  0.010000
# 6        NaN  3.012100  3.950077       NaN       NaN        NaN  0.010000
# 7        NaN  4.544670  5.047221  5.041580       NaN     0.0100  0.010000
# 8   1.505600  3.002686  4.160196       NaN  5.600000        NaN  0.010000
# 9   4.974312  2.000200       NaN       NaN  5.400000     0.0100  0.010000
# 16  7.138202  6.195509  6.487445       NaN  3.937011     0.0100  0.026663
# 17  1.507443  5.343773  5.397500  5.334784       NaN     0.0300  0.010000
# 18  4.028015  4.271909  5.888084  5.811900  5.632737     0.5011  0.100000
# 19  4.056540  6.460503  7.718873  8.236163  7.944475     0.1000  0.050000
# 23       NaN  5.805025       NaN       NaN       NaN     0.1000  0.050100
# 24       NaN  5.917763  7.088718       NaN       NaN        NaN  0.030000
# 28  2.591650  3.036323  3.179623       NaN       NaN     0.0100  0.010000
# 29       NaN       NaN  5.669106       NaN       NaN     0.0501  0.100000
# 30  2.116600  2.212100  4.050595       NaN       NaN        NaN  0.010000
# 34  4.836704  6.852978  5.799000  7.229000  6.485100     0.5500  0.551400
# 35  2.741697  6.682525  6.489067       NaN  8.299900     0.0100  0.010000
# 36  2.010000  5.541649       NaN       NaN       NaN     0.3004  0.300400
# 37  6.586258  7.442500  8.363997       NaN  7.229100        NaN  0.100000
# 38       NaN       NaN  5.487756       NaN       NaN        NaN  0.200200
# 39  4.593900  9.109600  5.793259       NaN  7.495800        NaN  0.501100
# 40  4.593900  6.167800  7.229100       NaN       NaN        NaN  0.010000
# 41  4.074200       NaN  5.848954  6.697100       NaN        NaN  0.501100
# 42  4.074200  4.854800  5.516029  6.697100       NaN        NaN       NaN
# 43  4.281800  5.116300  6.103877       NaN  7.495800     0.0200  0.010000
# 44  3.722128  4.333811  5.490065  6.396247       NaN     0.1000  0.150200
# 45  3.022500  3.964488  5.388509       NaN       NaN     0.1000  0.150200
# 46       NaN  3.556700       NaN       NaN  6.365900        NaN       NaN
# 47  4.070802  5.113490  7.229100  7.549300       NaN        NaN       NaN
# 48  7.687884  6.918391  7.062130       NaN       NaN     1.0047       NaN
# 49  2.324400       NaN  5.872434       NaN  7.977700     0.0200       NaN
# 50       NaN  4.000200  7.089484  7.200046  8.627572        NaN       NaN
# 51  2.624714  4.823836  5.356500       NaN  6.365900        NaN  0.010000
# 52  5.062500  6.000000  6.667774       NaN       NaN        NaN  0.100000
# 53       NaN       NaN  6.980100       NaN       NaN        NaN       NaN
# 54  3.530000       NaN  7.321335  7.513612       NaN     0.1000       NaN
# 55  3.530600  5.500000  6.659776  8.595550  7.591100     0.1000  0.010000
# 56  3.022500  6.572768  6.228313       NaN       NaN        NaN  0.050100
# 57  4.593900  6.167800  6.877741       NaN       NaN        NaN  0.200200
# 58  4.854800  5.116300  6.111413  6.962800       NaN        NaN  0.501100
# 59  3.530600       NaN  5.358055       NaN       NaN        NaN       NaN
# 60  2.522989  4.373755  6.193062  6.167800  7.229100     0.5011  0.501100
# 61       NaN       NaN  7.236570       NaN       NaN        NaN       NaN
# 62  2.018400  3.670794  5.594537  6.379200  7.977700        NaN  0.050100
# 63  4.063776  5.885235  6.301910       NaN       NaN     0.1000  0.100000
# 64       NaN       NaN  6.243493  6.200700  6.996700        NaN       NaN
# 65       NaN  7.168954       NaN       NaN       NaN        NaN  0.511200
# 66  4.074200       NaN  6.432939       NaN       NaN        NaN  0.067215
# 67  4.074200       NaN       NaN       NaN       NaN        NaN       NaN
# 68       NaN  5.640800       NaN       NaN  8.160089        NaN       NaN
# 69       NaN       NaN       NaN       NaN       NaN        NaN       NaN
# 71  3.530600  4.679838  5.570355       NaN  7.965877        NaN       NaN
# 72       NaN       NaN  4.907000       NaN       NaN        NaN  0.100000
# 73       NaN       NaN  4.200000       NaN       NaN        NaN       NaN
# 75  6.117602  6.105732  6.547993       NaN       NaN        NaN  0.501100
# 76       NaN  5.411889  6.904329       NaN       NaN     0.5011       NaN
# 77       NaN  4.549400  6.473993       NaN       NaN        NaN       NaN
# 79       NaN       NaN  7.442500       NaN       NaN        NaN       NaN
# 82       NaN       NaN  6.497100       NaN       NaN        NaN       NaN
#
#        60Usd   90Usd  180Usd    360Usd    720Usd  1080Usd  MayorUsd  \
# 3   0.010000     NaN  0.0700  0.133205  0.210000      NaN       NaN
# 4   0.010000     NaN  0.0100       NaN  0.960597      NaN       NaN
# 5   0.020000     NaN     NaN       NaN       NaN      NaN       NaN
# 6   0.010000     NaN  0.0800       NaN       NaN      NaN       NaN
# 7   0.010000  0.0400     NaN       NaN  2.277748      NaN       NaN
# 8   0.010000     NaN  0.1000       NaN       NaN      NaN       NaN
# 9   0.010000     NaN     NaN       NaN       NaN      NaN       NaN
# 16  0.037638     NaN     NaN  0.300200  0.400000      NaN       NaN
# 17  0.020000     NaN     NaN  0.800000  1.399900      NaN       NaN
# 18       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 19  0.100000     NaN     NaN  1.502188  1.800000      NaN       NaN
# 23       NaN     NaN     NaN       NaN       NaN      NaN    4.3338
# 24       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 28  0.010063  0.0500  0.0500  0.100000  0.200000      NaN       NaN
# 29       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 30       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 34  0.551400     NaN     NaN  4.508236  4.711319      NaN       NaN
# 35       NaN     NaN     NaN  3.011586  3.484727      NaN       NaN
# 36       NaN  3.0339  2.3132  4.486097       NaN      NaN    3.5567
# 37  0.150200     NaN     NaN       NaN  2.798900      NaN       NaN
# 38       NaN     NaN  1.0047       NaN       NaN      NaN       NaN
# 39       NaN     NaN     NaN       NaN  3.357301      NaN       NaN
# 40       NaN     NaN  0.0501  0.501100       NaN      NaN       NaN
# 41       NaN     NaN     NaN       NaN  1.611800      NaN       NaN
# 42       NaN  0.3004  1.0047       NaN       NaN      NaN       NaN
# 43       NaN  0.0501     NaN  0.200200       NaN   0.7022       NaN
# 44       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 45       NaN     NaN     NaN  2.500000       NaN      NaN       NaN
# 46       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 47       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 48  0.501102  1.2067  1.8081       NaN  2.998800      NaN       NaN
# 49       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 50       NaN     NaN     NaN  1.000000       NaN      NaN       NaN
# 51       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 52       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 53       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 54       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 55  0.100100     NaN  0.5006       NaN       NaN      NaN       NaN
# 56       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 57       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 58       NaN  1.0047     NaN       NaN       NaN      NaN       NaN
# 59       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 60  0.501122     NaN  1.0037       NaN  1.499900      NaN       NaN
# 61       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 62       NaN     NaN     NaN       NaN  1.510400      NaN       NaN
# 63       NaN  0.3003  0.5006       NaN  1.488900      NaN       NaN
# 64       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 65       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 66       NaN     NaN     NaN       NaN  1.814900      NaN       NaN
# 67       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 68  0.200100     NaN     NaN       NaN       NaN      NaN       NaN
# 69       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 71  2.018400     NaN     NaN       NaN       NaN      NaN       NaN
# 72  0.150200     NaN  1.0025       NaN       NaN      NaN       NaN
# 73       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 75       NaN     NaN  3.5567  4.038898  4.576500      NaN       NaN
# 76       NaN     NaN     NaN       NaN  4.060400      NaN       NaN
# 77       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 79       NaN     NaN     NaN       NaN       NaN      NaN       NaN
# 82       NaN     NaN     NaN       NaN       NaN      NaN       NaN
#
#                                  Tipo
# 3                    BANCOS MÚLTIPLES
# 4                    BANCOS MÚLTIPLES
# 5                    BANCOS MÚLTIPLES
# 6                    BANCOS MÚLTIPLES
# 7                    BANCOS MÚLTIPLES
# 8                    BANCOS MÚLTIPLES
# 9                    BANCOS MÚLTIPLES
# 16                      MICROFINANZAS
# 17                      MICROFINANZAS
# 18                      MICROFINANZAS
# 19                      MICROFINANZAS
# 23                      MICROFINANZAS
# 24                      MICROFINANZAS
# 28  ENTIDADES FINANCIERAS DE VIVIENDA
# 29  ENTIDADES FINANCIERAS DE VIVIENDA
# 30  ENTIDADES FINANCIERAS DE VIVIENDA
# 34                       COOPERATIVAS
# 35                       COOPERATIVAS
# 36                       COOPERATIVAS
# 37                       COOPERATIVAS
# 38                       COOPERATIVAS
# 39                       COOPERATIVAS
# 40                       COOPERATIVAS
# 41                       COOPERATIVAS
# 42                       COOPERATIVAS
# 43                       COOPERATIVAS
# 44                       COOPERATIVAS
# 45                       COOPERATIVAS
# 46                       COOPERATIVAS
# 47                       COOPERATIVAS
# 48                       COOPERATIVAS
# 49                       COOPERATIVAS
# 50                       COOPERATIVAS
# 51                       COOPERATIVAS
# 52                       COOPERATIVAS
# 53                       COOPERATIVAS
# 54                       COOPERATIVAS
# 55                       COOPERATIVAS
# 56                       COOPERATIVAS
# 57                       COOPERATIVAS
# 58                       COOPERATIVAS
# 59                       COOPERATIVAS
# 60                       COOPERATIVAS
# 61                       COOPERATIVAS
# 62                       COOPERATIVAS
# 63                       COOPERATIVAS
# 64                       COOPERATIVAS
# 65                       COOPERATIVAS
# 66                       COOPERATIVAS
# 67                       COOPERATIVAS
# 68                       COOPERATIVAS
# 69                       COOPERATIVAS
# 71                       COOPERATIVAS
# 72                       COOPERATIVAS
# 73                       COOPERATIVAS
# 75                               IFDS
# 76                               IFDS
# 77                               IFDS
# 79                               IFDS
# 82                               IFDS

# %% [markdown]
# #### Add appropriate index (if needed) to the dataframe

# %%
# Establecer el índice al nombre de la entidad
df.set_index("Entidad", inplace=True)

# Mostrar el DataFrame con el índice cambiado

# %%
df.head()
# Out:
#                        ahorroB       30b       60b  90b      180b      360b  \
# Entidad
# NACIONAL DE BOLIVIA   1.929171  0.115427  0.251310  NaN  1.507500  4.134283
# MERCANTIL SANTA CRUZ  1.549590  0.180000  0.390380  NaN  1.888729  3.190097
# CRÉDITO DE BOLIVIA    0.431098  0.046430  0.117885  NaN  3.530600       NaN
# BISA                  1.753244  0.032046  0.216280  NaN       NaN  3.012100
# UNIÓN                 0.154201  0.085047  0.149656  NaN       NaN  4.544670
#
#                           720b    1080b  Mayorb  ahorroUsd  30Usd  60Usd  \
# Entidad
# NACIONAL DE BOLIVIA   2.867602  3.36940     NaN     0.0100   0.01   0.01
# MERCANTIL SANTA CRUZ  4.583262      NaN     NaN        NaN   0.01   0.01
# CRÉDITO DE BOLIVIA         NaN      NaN     NaN     0.0001   0.01   0.02
# BISA                  3.950077      NaN     NaN        NaN   0.01   0.01
# UNIÓN                 5.047221  5.04158     NaN     0.0100   0.01   0.01
#
#                       90Usd  180Usd    360Usd    720Usd  1080Usd  MayorUsd  \
# Entidad
# NACIONAL DE BOLIVIA     NaN    0.07  0.133205  0.210000      NaN       NaN
# MERCANTIL SANTA CRUZ    NaN    0.01       NaN  0.960597      NaN       NaN
# CRÉDITO DE BOLIVIA      NaN     NaN       NaN       NaN      NaN       NaN
# BISA                    NaN    0.08       NaN       NaN      NaN       NaN
# UNIÓN                  0.04     NaN       NaN  2.277748      NaN       NaN
#
#                                   Tipo
# Entidad
# NACIONAL DE BOLIVIA   BANCOS MÚLTIPLES
# MERCANTIL SANTA CRUZ  BANCOS MÚLTIPLES
# CRÉDITO DE BOLIVIA    BANCOS MÚLTIPLES
# BISA                  BANCOS MÚLTIPLES
# UNIÓN                 BANCOS MÚLTIPLES

# %% [markdown]
# ###                                    3. Dataset Summary

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, NACIONAL DE BOLIVIA to IFD PROMUJER
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ahorroB    60 non-null     float64
#  1   30b        57 non-null     float64
#  2   60b        25 non-null     float64
#  3   90b        26 non-null     float64
#  4   180b       40 non-null     float64
#  5   360b       43 non-null     float64
#  6   720b       51 non-null     float64
#  7   1080b      17 non-null     float64
#  8   Mayorb     20 non-null     float64
#  9   ahorroUsd  24 non-null     float64
#  10  30Usd      40 non-null     float64
#  11  60Usd      19 non-null     float64
#  12  90Usd      8 non-null      float64
#  13  180Usd     15 non-null     float64
#  14  360Usd     13 non-null     float64
#  15  720Usd     19 non-null     float64
#  16  1080Usd    1 non-null      float64
#  17  MayorUsd   2 non-null      float64
#  18  Tipo       60 non-null     category
# dtypes: category(1), float64(18)
# memory usage: 9.2+ KB
# None

# %% [markdown]
# ##### Boliviano Currency:
#     ahorroB: Interest rate expressed in annual terms paid on savings accounts in the local currency
#     30b-Mayorb: Interest rate expressed in annual terms paid on Fixed-Term Deposits (ex: 30b is a 30 day deposit)
# ##### US dollar Currency:
#      ahorroUsd: Interest rate expressed in annual terms paid on US dollar savings accounts
#     30Usd-MayorUsd: Interest rate expressed in annual terms paid on Fixed-Term Deposits (ex: 30b is a 30 day deposit)

# %% [markdown]
# Getting the mean, standard deviation, minimun, maximun and quartile values for all columns

# %%
df.describe()
# Out:
#          ahorroB        30b        60b        90b       180b       360b  \
# count  60.000000  57.000000  25.000000  26.000000  40.000000  43.000000
# mean    1.975032   0.449516   0.666278   2.615178   3.765424   5.126727
# std     0.889666   0.695410   0.831809   1.571893   1.477863   1.478426
# min     0.016977   0.032046   0.070014   1.205400   1.505600   2.000200
# 25%     1.858799   0.180100   0.216280   1.508500   2.616448   4.203096
# 50%     2.018400   0.180100   0.400791   2.321051   3.875072   5.116300
# 75%     2.018800   0.501100   0.501200   3.420075   4.593900   6.136766
# max     5.401831   3.556700   3.814784   7.200391   7.687884   9.109600
#
#             720b      1080b     Mayorb  ahorroUsd      30Usd      60Usd  \
# count  51.000000  17.000000  20.000000  24.000000  40.000000  19.000000
# mean    5.979566   6.551899   7.038878   0.176608   0.141087   0.232649
# std     1.139693   1.244633   1.195995   0.253815   0.183822   0.469037
# min     2.867602   3.369400   3.937011   0.000100   0.010000   0.010000
# 25%     5.442628   6.167800   6.365900   0.010000   0.010000   0.010000
# 50%     6.111413   6.697100   7.362450   0.100000   0.050100   0.037638
# 75%     6.772757   7.229000   7.968833   0.150100   0.162700   0.175150
# max     8.363997   8.595550   8.627572   1.004700   0.551400   2.018400
#
#           90Usd     180Usd     360Usd     720Usd  1080Usd  MayorUsd
# count  8.000000  15.000000  13.000000  19.000000   1.0000  2.000000
# mean   0.748262   0.870327   1.775516   2.166426   0.7022  3.945250
# std    1.026642   1.016545   1.717684   1.392217      NaN  0.549493
# min    0.040000   0.010000   0.100000   0.200000   0.7022  3.556700
# 25%    0.050075   0.075000   0.300200   1.444400   0.7022  3.750975
# 50%    0.300350   0.500600   1.000000   1.800000   0.7022  3.945250
# 75%    1.055200   1.004700   3.011586   3.178051   0.7022  4.139525
# max    3.033900   3.556700   4.508236   4.711319   0.7022  4.333800

# %% [markdown]
# #### Partition of relevant data
# In this case, there are very few products offered in dollars, which is why we will subset the dataframe including
# all products in the Bolivian currency, and include only both the USD savings rate, and the 30 day Fixed-Term Deposit.
# As well, only columns with at least 25 observations will be now considered

# %%
#Non relevant: Last 7 columns before the last one
subset_df = df.iloc[:, :-8]
#at least 25 observations
min_observations = 24
subset_df = df.loc[:, df.count() >= min_observations]
# Display the subset DataFrame
subset_df
# Out:
#                            ahorroB       30b       60b       90b      180b  \
# Entidad
# NACIONAL DE BOLIVIA       1.929171  0.115427  0.251310       NaN  1.507500
# MERCANTIL SANTA CRUZ      1.549590  0.180000  0.390380       NaN  1.888729
# CRÉDITO DE BOLIVIA        0.431098  0.046430  0.117885       NaN  3.530600
# BISA                      1.753244  0.032046  0.216280       NaN       NaN
# UNIÓN                     0.154201  0.085047  0.149656       NaN       NaN
# ECONÓMICO                 1.087249  0.065127  0.201116  1.205500  1.505600
# GANADERO                  1.604116  0.050686  0.070014       NaN  4.974312
# SOLIDARIO                 2.121778  0.162463  0.397392  6.970803  7.138202
# FIE                       1.973674  0.129144  0.271320  1.205745  1.507443
# FORTALEZA                 4.072932  0.120512       NaN  1.205400  4.028015
# PRODEM                    1.406209  0.180000  0.500000  1.210000  4.056540
# DE LA COMUNIDAD           2.710278  0.101716       NaN  7.200391       NaN
# ECO FUTURO                1.887255  2.688022       NaN       NaN       NaN
# LA PRIMERA                2.769235  0.053945  0.186921  1.508500  2.591650
# PROMOTORA                 2.018400  0.200195       NaN       NaN       NaN
# PROGRESO                  2.018400  0.180100       NaN  2.118602  2.116600
# JESÚS  NAZARENO           2.020000  0.551400  0.551400  3.546200  4.836704
# SAN MARTÍN DE PORRES      0.050100  0.200200       NaN  1.812200  2.741697
# FÁTIMA                    2.018400  0.501100       NaN  1.508500  2.010000
# LA MERCED                 0.100000  0.200200  0.400712  2.523500  6.586258
# SAN PEDRO                 2.018400  0.501100       NaN       NaN       NaN
# LOYOLA                    2.018400  1.510400       NaN       NaN  4.593900
# CAT. TARIJA               2.018400  0.180100       NaN       NaN  4.593900
# SAN ANTONIO               3.452418  0.250300       NaN  3.556700  4.074200
# PIO X                     2.004099  0.501100       NaN  3.041700  4.074200
# INCAHUASSI                2.018400  0.180100       NaN  2.836200  4.281800
# QUILLACOLLO               2.018400  0.180100       NaN  2.528800  3.722128
# S.J. PUNATA               1.740693  0.586018       NaN  2.015000  3.022500
# TRINIDAD                  2.018400       NaN       NaN       NaN       NaN
# COMARAPA                  2.003466  0.180100  0.501190       NaN  4.070802
# SAN ROQUE                 2.018400  0.702200  0.702238       NaN  7.687884
# SAN MATEO                 0.619785  0.180100       NaN  1.307800  2.324400
# CHOROLQUE                 1.120206  0.501100       NaN       NaN       NaN
# M. F. GAINZA              2.018400  0.180100       NaN       NaN  2.624714
# MADRE Y MAESTRA           2.018400  0.501100       NaN  3.546200  5.062500
# E. G. CHACO               2.018400  0.180100       NaN       NaN       NaN
# CAT. POTOSÍ               1.000000  0.200000  0.200000  2.677797  3.530000
# ASUNCIÓN                  2.018400  0.180100  0.501162  2.015000  3.530600
# S. J. BERMEJO             2.018400  0.180100  0.501103  1.205400  3.022500
# MAG. RURAL                2.985016  0.200200       NaN  3.556700  4.593900
# SAN JOAQUÍN               2.018400  0.601600       NaN  3.660000  4.854800
# S.C BORROMEO              2.018400  0.501100       NaN  2.523500  3.530600
# CACEF                     1.773433  1.407109  1.900635       NaN  2.522989
# LA SAGRADA FAMILIA        5.401831  0.180000       NaN       NaN       NaN
# PROGRESO COOP             1.997819  0.250300       NaN       NaN  2.018400
# MAG RURAL CHUQUISACA      2.155440  0.180100       NaN       NaN  4.063776
# SAN PEDRO DE AIQUILE      2.018400  0.180100       NaN       NaN       NaN
# SAN MARTIN                3.041700  3.051800       NaN       NaN       NaN
# CRISTO REY CBBA           2.018400  0.300400       NaN       NaN  4.074200
# VIRGEN DE LOS REMEDIOS    2.018400  0.802900  1.510300       NaN  4.074200
# SAN FRANCISCO SOLANO      0.016977  0.180100  0.400799       NaN       NaN
# SOLUCREDIT SAN SILVESTRE  2.032108  0.200200       NaN       NaN       NaN
# PAULO VI                  2.018400  0.250300  2.018359  1.508500  3.530600
# HOSPICIO                  2.018400  0.200200  0.501200       NaN       NaN
# CANTERA                   2.000000  0.180100       NaN       NaN       NaN
# IFD CIDRE                 3.041700  3.556700  3.814784       NaN  6.117602
# IFD CRECER                2.734202  0.501100       NaN       NaN       NaN
# IFD DIACONÍA              1.990461  0.180100  0.400791       NaN       NaN
# IFD FUBODE                3.110509       NaN       NaN       NaN       NaN
# IFD PROMUJER              2.255136       NaN       NaN       NaN       NaN
#
#                               360b      720b  ahorroUsd     30Usd  \
# Entidad
# NACIONAL DE BOLIVIA       4.134283  2.867602     0.0100  0.010000
# MERCANTIL SANTA CRUZ      3.190097  4.583262        NaN  0.010000
# CRÉDITO DE BOLIVIA             NaN       NaN     0.0001  0.010000
# BISA                      3.012100  3.950077        NaN  0.010000
# UNIÓN                     4.544670  5.047221     0.0100  0.010000
# ECONÓMICO                 3.002686  4.160196        NaN  0.010000
# GANADERO                  2.000200       NaN     0.0100  0.010000
# SOLIDARIO                 6.195509  6.487445     0.0100  0.026663
# FIE                       5.343773  5.397500     0.0300  0.010000
# FORTALEZA                 4.271909  5.888084     0.5011  0.100000
# PRODEM                    6.460503  7.718873     0.1000  0.050000
# DE LA COMUNIDAD           5.805025       NaN     0.1000  0.050100
# ECO FUTURO                5.917763  7.088718        NaN  0.030000
# LA PRIMERA                3.036323  3.179623     0.0100  0.010000
# PROMOTORA                      NaN  5.669106     0.0501  0.100000
# PROGRESO                  2.212100  4.050595        NaN  0.010000
# JESÚS  NAZARENO           6.852978  5.799000     0.5500  0.551400
# SAN MARTÍN DE PORRES      6.682525  6.489067     0.0100  0.010000
# FÁTIMA                    5.541649       NaN     0.3004  0.300400
# LA MERCED                 7.442500  8.363997        NaN  0.100000
# SAN PEDRO                      NaN  5.487756        NaN  0.200200
# LOYOLA                    9.109600  5.793259        NaN  0.501100
# CAT. TARIJA               6.167800  7.229100        NaN  0.010000
# SAN ANTONIO                    NaN  5.848954        NaN  0.501100
# PIO X                     4.854800  5.516029        NaN       NaN
# INCAHUASSI                5.116300  6.103877     0.0200  0.010000
# QUILLACOLLO               4.333811  5.490065     0.1000  0.150200
# S.J. PUNATA               3.964488  5.388509     0.1000  0.150200
# TRINIDAD                  3.556700       NaN        NaN       NaN
# COMARAPA                  5.113490  7.229100        NaN       NaN
# SAN ROQUE                 6.918391  7.062130     1.0047       NaN
# SAN MATEO                      NaN  5.872434     0.0200       NaN
# CHOROLQUE                 4.000200  7.089484        NaN       NaN
# M. F. GAINZA              4.823836  5.356500        NaN  0.010000
# MADRE Y MAESTRA           6.000000  6.667774        NaN  0.100000
# E. G. CHACO                    NaN  6.980100        NaN       NaN
# CAT. POTOSÍ                    NaN  7.321335     0.1000       NaN
# ASUNCIÓN                  5.500000  6.659776     0.1000  0.010000
# S. J. BERMEJO             6.572768  6.228313        NaN  0.050100
# MAG. RURAL                6.167800  6.877741        NaN  0.200200
# SAN JOAQUÍN               5.116300  6.111413        NaN  0.501100
# S.C BORROMEO                   NaN  5.358055        NaN       NaN
# CACEF                     4.373755  6.193062     0.5011  0.501100
# LA SAGRADA FAMILIA             NaN  7.236570        NaN       NaN
# PROGRESO COOP             3.670794  5.594537        NaN  0.050100
# MAG RURAL CHUQUISACA      5.885235  6.301910     0.1000  0.100000
# SAN PEDRO DE AIQUILE           NaN  6.243493        NaN       NaN
# SAN MARTIN                7.168954       NaN        NaN  0.511200
# CRISTO REY CBBA                NaN  6.432939        NaN  0.067215
# VIRGEN DE LOS REMEDIOS         NaN       NaN        NaN       NaN
# SAN FRANCISCO SOLANO      5.640800       NaN        NaN       NaN
# SOLUCREDIT SAN SILVESTRE       NaN       NaN        NaN       NaN
# PAULO VI                  4.679838  5.570355        NaN       NaN
# HOSPICIO                       NaN  4.907000        NaN  0.100000
# CANTERA                        NaN  4.200000        NaN       NaN
# IFD CIDRE                 6.105732  6.547993        NaN  0.501100
# IFD CRECER                5.411889  6.904329     0.5011       NaN
# IFD DIACONÍA              4.549400  6.473993        NaN       NaN
# IFD FUBODE                     NaN  7.442500        NaN       NaN
# IFD PROMUJER                   NaN  6.497100        NaN       NaN
#
#                                                        Tipo
# Entidad
# NACIONAL DE BOLIVIA                        BANCOS MÚLTIPLES
# MERCANTIL SANTA CRUZ                       BANCOS MÚLTIPLES
# CRÉDITO DE BOLIVIA                         BANCOS MÚLTIPLES
# BISA                                       BANCOS MÚLTIPLES
# UNIÓN                                      BANCOS MÚLTIPLES
# ECONÓMICO                                  BANCOS MÚLTIPLES
# GANADERO                                   BANCOS MÚLTIPLES
# SOLIDARIO                                     MICROFINANZAS
# FIE                                           MICROFINANZAS
# FORTALEZA                                     MICROFINANZAS
# PRODEM                                        MICROFINANZAS
# DE LA COMUNIDAD                               MICROFINANZAS
# ECO FUTURO                                    MICROFINANZAS
# LA PRIMERA                ENTIDADES FINANCIERAS DE VIVIENDA
# PROMOTORA                 ENTIDADES FINANCIERAS DE VIVIENDA
# PROGRESO                  ENTIDADES FINANCIERAS DE VIVIENDA
# JESÚS  NAZARENO                                COOPERATIVAS
# SAN MARTÍN DE PORRES                           COOPERATIVAS
# FÁTIMA                                         COOPERATIVAS
# LA MERCED                                      COOPERATIVAS
# SAN PEDRO                                      COOPERATIVAS
# LOYOLA                                         COOPERATIVAS
# CAT. TARIJA                                    COOPERATIVAS
# SAN ANTONIO                                    COOPERATIVAS
# PIO X                                          COOPERATIVAS
# INCAHUASSI                                     COOPERATIVAS
# QUILLACOLLO                                    COOPERATIVAS
# S.J. PUNATA                                    COOPERATIVAS
# TRINIDAD                                       COOPERATIVAS
# COMARAPA                                       COOPERATIVAS
# SAN ROQUE                                      COOPERATIVAS
# SAN MATEO                                      COOPERATIVAS
# CHOROLQUE                                      COOPERATIVAS
# M. F. GAINZA                                   COOPERATIVAS
# MADRE Y MAESTRA                                COOPERATIVAS
# E. G. CHACO                                    COOPERATIVAS
# CAT. POTOSÍ                                    COOPERATIVAS
# ASUNCIÓN                                       COOPERATIVAS
# S. J. BERMEJO                                  COOPERATIVAS
# MAG. RURAL                                     COOPERATIVAS
# SAN JOAQUÍN                                    COOPERATIVAS
# S.C BORROMEO                                   COOPERATIVAS
# CACEF                                          COOPERATIVAS
# LA SAGRADA FAMILIA                             COOPERATIVAS
# PROGRESO COOP                                  COOPERATIVAS
# MAG RURAL CHUQUISACA                           COOPERATIVAS
# SAN PEDRO DE AIQUILE                           COOPERATIVAS
# SAN MARTIN                                     COOPERATIVAS
# CRISTO REY CBBA                                COOPERATIVAS
# VIRGEN DE LOS REMEDIOS                         COOPERATIVAS
# SAN FRANCISCO SOLANO                           COOPERATIVAS
# SOLUCREDIT SAN SILVESTRE                       COOPERATIVAS
# PAULO VI                                       COOPERATIVAS
# HOSPICIO                                       COOPERATIVAS
# CANTERA                                        COOPERATIVAS
# IFD CIDRE                                              IFDS
# IFD CRECER                                             IFDS
# IFD DIACONÍA                                           IFDS
# IFD FUBODE                                             IFDS
# IFD PROMUJER                                           IFDS

# %% [markdown]
# ### 4. Data Visualization

# %% [markdown]
# ##### Categorical variables

# %%
# Create the count plot using Seaborn
# Set the font size for the plot
sns.set(font_scale=1.5)
sns.set_style('whitegrid')  # Optional: Set a background style for the plot
plt.figure(figsize=(20, 6))
ax=sns.countplot(x=subset_df['Tipo'])

# Add labels and title
plt.xlabel('Institution Type')
plt.ylabel('Count')
plt.title('Financial Institutions by Type')
# Add data labels (counts) to the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')


# Show the plot
plt.show()

# %% [markdown]
# ##### Continuous variables

# %% [markdown]
# Histogram of continuos variables

# %%
f, axes = plt.subplots(len(subset_df.columns), figsize=(20, 65), sharex=False) 
for i in range(len(subset_df.columns)-1):
    d = sns.histplot( subset_df[subset_df.columns[i]], ax=axes[i])
    d.set_xlabel(subset_df.columns[i],fontsize=15)

# %% [markdown]
# Barplot for categorical variables

# %%
# Reassigning the categoric value
Bs_df= df.iloc[:, :2]
Bs_df['Tipo'] = df['Tipo']

# %% [markdown]
# Visualizing violin plots for specific columns, categorized according to the financial institution type.

# %%
n_rows = 2
n_cols = 1
count = 0

plt.subplots(n_rows, n_cols, figsize=(25, 15))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
for i in range(n_rows):
    for j in range(n_cols):
        plt.subplot(n_rows, n_cols, count+1)
        sns.violinplot(x="Tipo",y=Bs_df.columns[count],data=Bs_df)
        count = count+1
plt.show()

# %% [markdown]
# Visualizing boxplots for specific columns, categorized according to the financial institution type.

# %%
#sns.catplot(x="type",y="fixed acidity",kind='box',data=df_train)

n_rows = 2
n_cols = 1
count = 0

plt.subplots(n_rows, n_cols, figsize=(25, 25))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
for i in range(n_rows):
    for j in range(n_cols):
        plt.subplot(n_rows, n_cols, count+1)
        sns.boxplot(x="Tipo",y=Bs_df.columns[count],data=Bs_df)
        count = count+1
plt.show()

# %% [markdown]
# The boxplot of two variables show us the presence of outliers

# %% [markdown]
# ##### Outlier detection
# Making use of the IQR detection method

# %%
# Function to detect outliers using IQR method within each group
def detect_outliers_iqr_group(column):
    if column.dtype == 'object':
        return column  # For categorical columns, return as is
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column[(column < lower_bound) | (column > upper_bound)]

# %%
# Detecting outliers for each group using IQR method. example with the 360 day Fixed Deposit in Bolivianos variable
outliers_iqr_grouped = subset_df.groupby('Tipo')['360b'].apply(detect_outliers_iqr_group)

print("Outliers using IQR method, grouped by Category:")
print(outliers_iqr_grouped)
# Out:
# Outliers using IQR method, grouped by Category:
# Tipo           Entidad
# COOPERATIVAS   LOYOLA       9.109600
# MICROFINANZAS  FORTALEZA    4.271909
# Name: 360b, dtype: float64

# %% [markdown]
# Industry knowledge: Because these are rates paid to customers, it might be more interesting to know which financial
#     institutions have the highest rates, both for regulation and profit purposes

# %%
# Function to detect outliers using IQR method within each group
def high_outliers_iqr_group(column):
    if column.dtype == 'object':
        return column  # For categorical columns, return as is
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column[(column > upper_bound)]

# %%
# Detect outliers for each group using IQR method
outliers_iqr_grouped = subset_df.groupby('Tipo')['360b'].apply(high_outliers_iqr_group)

print("Outliers using IQR method, grouped by Category:")
print(outliers_iqr_grouped)
# Out:
# Outliers using IQR method, grouped by Category:
# Tipo          Entidad
# COOPERATIVAS  LOYOLA     9.1096
# Name: 360b, dtype: float64

# %% [markdown]
# We now know, that if the objective is to seek the highest profitability for a 1 year period, this entity pays the most.

# %% [markdown]
# ##### Absolute Deviation of a Value

# %% [markdown]
# To understand how far is a value from the mean, we use the concept of absolute deviation.
# Example provided: Loyola's 360 day Fixed Deposit Rate, contrasted to the Cooperativa group mean for the same product.

# %%
subset_df.loc['LOYOLA','360b']
# Out:
# 9.109599999999999

# %%
# Finding the group mean, given his entity type "Cooperativa".
grouped_means = df.groupby('Tipo').mean()
grouped_means.loc['COOPERATIVAS','ahorroB']
# Out:
# 1.9457202725905693

# %%
abs(subset_df.loc['LOYOLA','360b']-grouped_means.loc['COOPERATIVAS','ahorroB'])
# Out:
# 7.163879727409429
